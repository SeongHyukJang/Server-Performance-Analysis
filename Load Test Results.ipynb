# %%
import os
from IPython.display import Image

# %%
os.chdir('./Load Test')
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test

# %%
Concurrent_get_json = Image('GET_json.png')
Concurrent_post_json = Image('POST_json.png')
Concurrent_get_calc = Image('GET_calc.png')
Concurrent_get_html = Image('GET_html.png')

# %%
os.chdir('./CPU & Memory')
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test/CPU & Memory

# %%
cpu_mem_get_json = Image('GET_json.png')
cpu_mem_post_json = Image('POST_json.png')
cpu_mem_get_calc = Image('GET_calc.png')
cpu_mem_get_html = Image('GET_html.png')

# %% [markdown]
# ## GET json

# %%
Concurrent_get_json

# %%
cpu_mem_get_json

# %% [markdown]
# ## POST json

# %%
Concurrent_post_json

# %%
cpu_mem_post_json

# %% [markdown]
# ## GET calc

# %%
Concurrent_get_calc

# %%
cpu_mem_get_calc

# %% [markdown]
# ## GET html

# %%
Concurrent_get_html

# %%
cpu_mem_get_html
