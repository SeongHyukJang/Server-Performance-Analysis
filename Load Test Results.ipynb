# %%
import os
from IPython.display import Image

# %%
os.chdir('./Load Test')
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test

# %%
Image('GET_json.png')

# %%
Image('POST_json.png')

# %%
Image('GET_calc.png')

# %%
Image('GET_html.png')

# %%
os.chdir('./CPU & Memory/Python')

# %%
Image('GET_json.png')

# %%
Image('POST_json.png')

# %%
Image('GET_calc.png')

# %%
Image('GET_html.png')

# %%
os.chdir('../Javascript')

# %%
Image('GET_json.png')

# %%
Image('POST_json.png')

# %%
Image('GET_calc.png')

# %%
Image('GET_html.png')
