# %%
import os
from IPython.display import Image

# %%
os.chdir("./Load Test")
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test

# %%
Concurrent_get_json = Image('GET_json.png')
Concurrent_post_json = Image('POST_json.png')
Concurrent_get_calc = Image('GET_calc.png')
Concurrent_get_html = Image('GET_html.png')

# %%
os.chdir('./CPU & Memory/CPU')
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test/CPU & Memory/CPU

# %%
cpu_get_json = Image('get-json-cpu.png')
cpu_post_json = Image('post-json-cpu.png')
cpu_get_calc = Image('get-calc-cpu.png')
cpu_get_html = Image('get-html-cpu.png')

# %%
os.chdir('./../Memory')
print(os.getcwd())
# Out:
# /home/jsh/GitHub/SWCON_Project/Load Test/CPU & Memory/Memory

# %%
mem_get_json = Image('get-json-mem.png')
mem_post_json = Image('post-json-mem.png')
mem_get_calc = Image('get-calc-mem.png')
mem_get_html = Image('get-html-mem.png')

# %% [markdown]
# ## GET json

# %%
Concurrent_get_json

# %%
cpu_get_json

# %%
mem_get_json

# %% [markdown]
# ## POST json

# %%
Concurrent_post_json

# %%
cpu_post_json

# %%
mem_post_json

# %% [markdown]
# ## GET calc

# %%
Concurrent_get_calc

# %%
cpu_get_calc

# %%
mem_get_calc

# %% [markdown]
# ## GET html

# %%
Concurrent_get_html

# %%
cpu_get_html

# %%
mem_get_html
